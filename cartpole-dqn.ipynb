# %%
import random
import gym
import numpy as np
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam



ENV_NAME = "CartPole-v1"

GAMMA = 0.95
LEARNING_RATE = 0.001

MEMORY_SIZE = 2000
BATCH_SIZE = 20

EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.01
EXPLORATION_DECAY = 0.995


class DQNSolver:

    def __init__(self, observation_space, action_space):
        self.exploration_rate = EXPLORATION_MAX

        self.action_space = action_space
        self.memory = deque(maxlen=MEMORY_SIZE)

        self.model = Sequential()
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))
        self.model.add(Dense(24, activation="relu"))
        self.model.add(Dense(self.action_space, activation="linear"))
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() < self.exploration_rate:
            return random.randrange(self.action_space)
        q_values = self.model.predict(state)
        return np.argmax(q_values[0])

    def experience_replay(self):
        if len(self.memory) < BATCH_SIZE:
            return
        batch = random.sample(self.memory, BATCH_SIZE)
        for state, action, reward, state_next, terminal in batch:
            q_update = reward
            if not terminal:
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
            q_values = self.model.predict(state)
            q_values[0][action] = q_update
            self.model.fit(state, q_values, verbose=0)
        self.exploration_rate *= EXPLORATION_DECAY
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)
    #epsilon gradient policy

def cartpole():
    env = gym.make(ENV_NAME)
    observation_space = env.observation_space.shape[0]
    action_space = env.action_space.n
    dqn_solver = DQNSolver(observation_space, action_space)
    run = 0
    while True:
        run += 1
        state = env.reset()
        state = np.reshape(state, [1, observation_space])
        step = 0
        while True:
            step += 1
            #env.render()
            action = dqn_solver.act(state)
            state_next, reward, terminal, info = env.step(action)
            reward = reward if not terminal else -reward
            state_next = np.reshape(state_next, [1, observation_space])
            dqn_solver.remember(state, action, reward, state_next, terminal)
            state = state_next
            if terminal:
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
                break
            dqn_solver.experience_replay()
        if run==200:
            break
    
if __name__ == "__main__":
    cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 14
# Run: 2, exploration: 0.9091562615825302, score: 25
# Run: 3, exploration: 0.7861544476842928, score: 30
# Run: 4, exploration: 0.7477194593032545, score: 11
# Run: 5, exploration: 0.6797938283326578, score: 20
# Run: 6, exploration: 0.6118738784280476, score: 22
# Run: 7, exploration: 0.5647174463480732, score: 17
# Run: 8, exploration: 0.5371084840724134, score: 11
# Run: 9, exploration: 0.483444593917636, score: 22
# Run: 10, exploration: 0.46211964903917074, score: 10
# Run: 11, exploration: 0.42650460709830135, score: 17
# Run: 12, exploration: 0.4036245882390106, score: 12
# Run: 13, exploration: 0.37816180712868996, score: 14
# Run: 14, exploration: 0.3596735257153405, score: 11
# Run: 15, exploration: 0.3386767948568688, score: 13
# Run: 16, exploration: 0.3253644408394192, score: 9
# Run: 17, exploration: 0.3125753549412418, score: 9
# Run: 18, exploration: 0.29285644267656924, score: 14
# Run: 19, exploration: 0.27853872940185365, score: 11
# Run: 20, exploration: 0.26359640222486147, score: 12
# Run: 21, exploration: 0.2519690537792925, score: 10
# Run: 22, exploration: 0.23965031961336, score: 11
# Run: 23, exploration: 0.22793384675362674, score: 11
# Run: 24, exploration: 0.21248679717794605, score: 15
# Run: 25, exploration: 0.19908200231898848, score: 14
# Run: 26, exploration: 0.1903004112552766, score: 10
# Run: 27, exploration: 0.182820281282489, score: 9
# Run: 28, exploration: 0.17475600159032884, score: 10
# Run: 29, exploration: 0.16704744067563246, score: 10
# Run: 30, exploration: 0.15967890763313974, score: 10
# Run: 31, exploration: 0.1526354036900377, score: 10
# Run: 32, exploration: 0.14590259167570602, score: 10
# Run: 33, exploration: 0.13946676683816583, score: 10
# Run: 34, exploration: 0.13264825480308728, score: 11
# Run: 35, exploration: 0.12807462877562611, score: 8
# Run: 36, exploration: 0.12365869841532712, score: 8
# Run: 37, exploration: 0.11820406108847166, score: 10
# Run: 38, exploration: 0.10068643904747315, score: 33
# Run: 39, exploration: 0.07995261925574046, score: 47
# Run: 40, exploration: 0.06844601986126451, score: 32
# Run: 41, exploration: 0.06038446427088321, score: 26
# Run: 42, exploration: 0.05066791621302729, score: 36
# Run: 43, exploration: 0.046296535966244, score: 19
# Run: 44, exploration: 0.03884689602888724, score: 36
# Run: 45, exploration: 0.030539660091838977, score: 49
# Run: 46, exploration: 0.024866262250633264, score: 42
# Run: 47, exploration: 0.018592988164936427, score: 59
# Run: 48, exploration: 0.015445542985048652, score: 38
# Run: 49, exploration: 0.012576201611761997, score: 42
# Run: 50, exploration: 0.01, score: 59
# Run: 51, exploration: 0.01, score: 59
# Run: 52, exploration: 0.01, score: 80
# Run: 53, exploration: 0.01, score: 130
# Run: 54, exploration: 0.01, score: 204
# Run: 55, exploration: 0.01, score: 46
# Run: 56, exploration: 0.01, score: 74
# Run: 57, exploration: 0.01, score: 69
# Run: 58, exploration: 0.01, score: 109
# Run: 59, exploration: 0.01, score: 52
# Run: 60, exploration: 0.01, score: 93
# Run: 61, exploration: 0.01, score: 36
# Run: 62, exploration: 0.01, score: 114
# Run: 63, exploration: 0.01, score: 25
# Run: 64, exploration: 0.01, score: 41
# Run: 65, exploration: 0.01, score: 43
# Run: 66, exploration: 0.01, score: 103
# Run: 67, exploration: 0.01, score: 111
# Run: 68, exploration: 0.01, score: 27
# Run: 69, exploration: 0.01, score: 27
# Run: 70, exploration: 0.01, score: 38
# Run: 71, exploration: 0.01, score: 26
# Run: 72, exploration: 0.01, score: 79
# Run: 73, exploration: 0.01, score: 36
# Run: 74, exploration: 0.01, score: 100
# Run: 75, exploration: 0.01, score: 48
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-40e04494b7a2> in <module>
#      88
#      89 if __name__ == "__main__":
# ---> 90     cartpole()
#
# <ipython-input-8-40e04494b7a2> in cartpole()
#      83                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
#      84                 break
# ---> 85             dqn_solver.experience_replay()
#      86         if run==200:
#      87             break
#
# <ipython-input-8-40e04494b7a2> in experience_replay(self)
#      52             q_update = reward
#      53             if not terminal:
# ---> 54                 q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
#      55             q_values = self.model.predict(state)
#      56             q_values[0][action] = q_update
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# ~/.local/lib/python3.6/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# ~/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/.conda/envs/mll/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
